# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
# !pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# C:\Users\salyu\AppData\Local\Temp\ipykernel_13732\2160715986.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# chromrdriver = "/home/chromedriver"
# os.environ["webdriver.chrome.driver"] = chromrdriver
# driver = webdriver.Chrome(chromrdriver)
driver.get("https://eliteraturebook.com/index")

ScrollNumber = 500
for i in range(1,ScrollNumber):
    driver.execute_script("window.scrollTo(1,50000)")
    time.sleep(5)

file = open('DS.html', 'w',encoding="utf8") 
file.write(driver.page_source)
file.close()

driver.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <cell line: 7>()
#       7 for i in range(1,ScrollNumber):
#       8     driver.execute_script("window.scrollTo(1,50000)")
# ----> 9     time.sleep(5)
#      11 file = open('DS.html', 'w',encoding="utf8")
#      12 file.write(driver.page_source)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

#first we downloaded the library HTML 
# Parse the HTML using BeautifulSoup

url = "Datasethtml.html"
data = open(url,'r',encoding="utf8")
soup = BeautifulSoup(data, 'html.parser')

book_links = [a['href'] for a in soup.find_all('a', href=True) if 'https://eliteraturebook.com/books/view/' in a['href']]

#print (len(book_links))
# Out:
# 6564

# %%
for link in book_links[5500:]:

    book_response = requests.get(link)
    book_content = book_response.content
    
    soup = BeautifulSoup(book_content, 'html.parser')
    book_download = [a['href'] for a in soup.find_all('a', href=True) if 'download' in a['href']]
    print(book_download)
    if len(book_download) != 0: 
        book_response = requests.get(book_download[0])
        book_name = "books" + str(counter)+".pdf"
        with open(book_name, 'wb') as f:
            f.write(book_response.content)
            counter = counter +1
# Out:
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY2IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY2IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY1IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY1IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY1IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY0IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY0IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDY0IiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDYzIiwidHlwZSI6InBkZiJ9']
# ['https://eliteraturebook.com/books/download/?hash=eyJpZCI6IjE2NDYzIiwidHlwZSI6InBkZiJ9']
# ...
